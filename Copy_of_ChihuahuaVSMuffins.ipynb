# %% [markdown]
# <a href="https://colab.research.google.com/github/Athena-yousra/face_recognition/blob/main/Copy_of_ChihuahuaVSMuffins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import os
import tensorflow_datasets as tfds
dataset, info = tfds.load('lfw', split='train', with_info=True)
images = []
labels = []

for example in dataset.take(100):  # Take a subset of the dataset for demonstration
    image = example['image']
    # Convert image to grayscale and resize
    image = tf.image.rgb_to_grayscale(image)
    image = tf.image.resize(image, (250, 250))
    images.append(image.numpy())
    labels.append(example['label'].numpy())

images = np.array(images)
labels = np.array(labels)

# Split the dataset into training and testing sets
xtr, xts, ytr, yts = train_test_split(images, labels, train_size=0.8, test_size=0.2, random_state=42)

# Determine the number of classes
num_classes = len(np.unique(labels))

# Define the CNN model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(250, 250, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Encode the labels


# Compile the model with sparse_categorical_crossentropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_18 (Conv2D)          (None, 248, 248, 32)      320
#
#  max_pooling2d_18 (MaxPooli  (None, 124, 124, 32)      0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 122, 122, 64)      18496
#
#  max_pooling2d_19 (MaxPooli  (None, 61, 61, 64)        0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 59, 59, 128)       73856
#
#  max_pooling2d_20 (MaxPooli  (None, 29, 29, 128)       0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 107648)            0
#
#  dense_12 (Dense)            (None, 128)               13779072
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 90)                11610
#
# ...
# Total params: 13883354 (52.96 MB)
# Trainable params: 13883354 (52.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
ytr_encoded = label_encoder.fit_transform(ytr).astype(np.float32)
yts_encoded = label_encoder.transform(yts).astype(np.float32)

# Train the model
history = model.fit(x=xtr, y=ytr_encoded, epochs=10, validation_data=(xts, yts_encoded))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in _encode(values, uniques, check_unknown)
#     223         try:            return _map_to_integer(values, uniques)
# --> 224
#     225         except KeyError as e:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in _map_to_integer(values, uniques)
#     163     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164     return np.array([table[v] for v in values])
#     165
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in <listcomp>(.0)
#     163     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164     return np.array([table[v] for v in values])
#     165
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in __missing__(self, key)
# ...

# %%
# Evaluate the model
loss, accuracy = model.evaluate(xts, yts)
print("Test Accuracy:", accuracy)

# Plot training history
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-9-c3b182a3ecb2> in <cell line: 2>()
#       1 # Evaluate the model
# ----> 2 loss, accuracy = model.evaluate(xts, yts)
#       3 print("Test Accuracy:", accuracy)
#       4
#       5 # Plot training history
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ...
